# %% [markdown]
# # Description

# %% [markdown]
# This notebook aggregates the raw mechanical loading data files into a single file for easy loading and manipulation.

# %% [markdown]
# # Imports

# %%
import os

import pandas as pd

from IPython.core.display import display, HTML

# %% [markdown]
# # Parameters

# %%
raw_dirname = "../data/mechanical_loading_datasets"
raw_basenames = ["500mAh1.xlsx","500mAh2.xlsx","500mAh3.xlsx","1500mAh1.xlsx","1500mAh2.xlsx","1500mAh3.xlsx","2000mAh1.xlsx","2000mAh2.xlsx"]

results_dirname = "../data"
results_basename = "raw_mechanical_loading_data.csv.gz"

# %% [markdown]
# # Data Loading

# %% [markdown]
# ## Helper Functions

# %%
def process_load_df(load_df):
    load_df = load_df.copy()
    columns = list()
    for column in load_df.columns:
        columns.append((
            "{} SOC".format(int(100*float(column[0]))),
            column[1].title()
        ))
    load_df.columns = pd.MultiIndex.from_tuples(columns)
    
    df_list = list()
    for first_level in load_df.columns.levels[0]:
        columns = [
            (first_level,tmp_second)
            for tmp_first,tmp_second in load_df.columns
            if first_level == tmp_first
        ]
        tmp_df = load_df[columns]
        tmp_df = tmp_df[tmp_df[(first_level,"Time [Sec]")].notna()]
        tmp_df.set_index((first_level,"Time [Sec]"), inplace=True)
        tmp_df.index.rename("Time [Sec]", inplace=True)
        tmp_df.sort_index(axis="index", inplace=True)
        df_list.append(tmp_df)
    return pd.concat(df_list, axis="columns", join="outer")

# %%
def process_voltage_df(voltage_df):
    voltage_df = voltage_df.copy()
    columns = list()
    for column in voltage_df.columns:
        columns.append((
            "{} SOC".format(int(100*float(column[0]))),
            column[1].title()
        ))
    voltage_df.columns = pd.MultiIndex.from_tuples(columns)
    
    df_list = list()
    for first_level in voltage_df.columns.levels[0]:
        columns = [
            (first_level,tmp_second)
            for tmp_first,tmp_second in voltage_df.columns
            if first_level == tmp_first
        ]
        tmp_df = voltage_df[columns]
        tmp_df = tmp_df[tmp_df[(first_level,"Time [Sec]")].notna()]
        tmp_df.set_index((first_level,"Time [Sec]"), inplace=True)
        tmp_df.index.rename("Time [Sec]", inplace=True)
        tmp_df.sort_index(axis="index", inplace=True)
        df_list.append(tmp_df)
    return pd.concat(df_list, axis="columns", join="outer")

# %%
def process_temperature_df(temperature_df):
    temperature_df = temperature_df.copy()
    columns = list()
    for column in temperature_df.columns:
        first = "{} SOC".format(int(100*float(column[0])))
        if column[1].startswith("time/s") :
            second = "Time [Sec]"
        elif column[1].startswith("temperature") :
            second = "Temperature [C]"
        else:
            raise ValueError(column[1])
        columns.append((first,second))
    temperature_df.columns = pd.MultiIndex.from_tuples(columns)
    
    df_list = list()
    for first_level in temperature_df.columns.levels[0]:
        columns = [
            (first_level,tmp_second)
            for tmp_first,tmp_second in temperature_df.columns
            if first_level == tmp_first
        ]
        tmp_df = temperature_df[columns]
        tmp_df = tmp_df[tmp_df[(first_level,"Time [Sec]")].notna()]
        tmp_df.set_index((first_level,"Time [Sec]"), inplace=True)
        tmp_df.index.rename("Time [Sec]", inplace=True)
        tmp_df.sort_index(axis="index", inplace=True)
#         display(tmp_df)
#         if not tmp_df.index.is_unique:
#             idx = tmp_df.duplicated(keep=False).values
#             print("HERE", sum(idx))
#             print(type(idx))
#             print(idx.shape)
#             print(idx)
#             with pd.option_context("display.min_rows", 20, "display.max_rows", 20, "display.max_columns", None):
#                 display(
#                     tmp_df[idx]
#                 )
#                 display(
#                     tmp_df.index[idx]
#                 )
        df_list.append(tmp_df)
    return pd.concat(df_list, axis="columns", join="outer")

# %% [markdown]
# ## File Loading

# %%
df_list = list()
for raw_basename in raw_basenames:
    if raw_basename == "500mAh3.xlsx":
        continue
    filename = os.path.join(raw_dirname, raw_basename)
    display(HTML("<h1>{}</h1>".format(raw_basename)))
    xl_file = pd.ExcelFile(filename)
    print(xl_file.sheet_names)
    
    load_df = xl_file.parse("load", header=[0, 1])
    voltage_df = xl_file.parse("voltage", header=[0, 1])
    temperature_df = xl_file.parse("temperature", header=[0, 1])
    
#     display(load_df.head(1))
#     display(voltage_df.head(1))
#     display(temperature_df.head(1))
    
    new_load_df = process_load_df(load_df)
    new_voltage_df = process_voltage_df(voltage_df)
    new_temperature_df = process_temperature_df(temperature_df)
    
#     display(new_load_df.head(1))
#     display(new_voltage_df.head(1))
#     display(new_temperature_df.head(1))
    
    data_df = [new_load_df, new_voltage_df, new_temperature_df]
    data_df = pd.concat(data_df, axis="columns", join="outer")
    
    new_name = raw_basename.replace("mAh", " mAh ").replace(".xlsx", "")
    data_df.columns = pd.MultiIndex.from_tuples([
        (new_name,) + column
        for column in data_df.columns
    ])
    
#     display(data_df.head(1))

    df_list.append(data_df)
data_df = pd.concat(df_list, axis="columns", join="outer")

def column_compare(column):
    first,second,third = column
    first = (int(first.split()[0]), int(first.split()[-1]))
    second = int(second.split()[0])
    if "2000" in third:
        third = 0
    elif "Voltage" in third:
        third = 1
    else:
        third = 2
    return first,second,third

data_df = data_df[sorted(data_df.columns, key=column_compare)]

data_df.info(verbose=True)
with pd.option_context("display.max_rows", 10, "display.max_columns", None):
    display(data_df)
    display(data_df.describe())
# Out:
# <h1>500mAh1.xlsx</h1>
# ['load', 'voltage', 'temperature']
# <h1>500mAh2.xlsx</h1>
# ['load', 'voltage', 'temperature']
# <h1>1500mAh1.xlsx</h1>
# ['load', 'voltage', 'temperature']
# <h1>1500mAh2.xlsx</h1>
# ['load', 'voltage', 'temperature']
# <h1>1500mAh3.xlsx</h1>
# ['load', 'voltage', 'temperature']
# <h1>2000mAh1.xlsx</h1>
# ['load', 'voltage', 'temperature']
# <h1>2000mAh2.xlsx</h1>
# ['load', 'voltage', 'temperature']
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 30009 entries, 0.0 to 3011.4
# Data columns (total 105 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   (500 mAh 1, 20 SOC, 2000 Pounds [Pounds])    float64
#  1   (500 mAh 1, 20 SOC, Voltage [V])             float64
#  2   (500 mAh 1, 20 SOC, Temperature [C])         float64
#  3   (500 mAh 1, 40 SOC, 2000 Pounds [Pounds])    float64
#  4   (500 mAh 1, 40 SOC, Voltage [V])             float64
#  5   (500 mAh 1, 40 SOC, Temperature [C])         float64
#  6   (500 mAh 1, 60 SOC, 2000 Pounds [Pounds])    float64
#  7   (500 mAh 1, 60 SOC, Voltage [V])             float64
#  8   (500 mAh 1, 60 SOC, Temperature [C])         float64
#  9   (500 mAh 1, 80 SOC, 2000 Pounds [Pounds])    float64
#  10  (500 mAh 1, 80 SOC, Voltage [V])             float64
#  11  (500 mAh 1, 80 SOC, Temperature [C])         float64
#  12  (500 mAh 1, 100 SOC, 2000 Pounds [Pounds])   float64
#  13  (500 mAh 1, 100 SOC, Voltage [V])            float64
#  14  (500 mAh 1, 100 SOC, Temperature [C])        float64
#  15  (500 mAh 2, 20 SOC, 2000 Pounds [Pounds])    float64
#  16  (500 mAh 2, 20 SOC, Voltage [V])             float64
#  17  (500 mAh 2, 20 SOC, Temperature [C])         float64
#  18  (500 mAh 2, 40 SOC, 2000 Pounds [Pounds])    float64
#  19  (500 mAh 2, 40 SOC, Voltage [V])             float64
#  20  (500 mAh 2, 40 SOC, Temperature [C])         float64
#  21  (500 mAh 2, 60 SOC, 2000 Pounds [Pounds])    float64
#  22  (500 mAh 2, 60 SOC, Voltage [V])             float64
#  23  (500 mAh 2, 60 SOC, Temperature [C])         float64
#  24  (500 mAh 2, 80 SOC, 2000 Pounds [Pounds])    float64
#  25  (500 mAh 2, 80 SOC, Voltage [V])             float64
#  26  (500 mAh 2, 80 SOC, Temperature [C])         float64
#  27  (500 mAh 2, 100 SOC, 2000 Pounds [Pounds])   float64
#  28  (500 mAh 2, 100 SOC, Voltage [V])            float64
#  29  (500 mAh 2, 100 SOC, Temperature [C])        float64
#  30  (1500 mAh 1, 20 SOC, 2000 Pounds [Pounds])   float64
#  31  (1500 mAh 1, 20 SOC, Voltage [V])            float64
#  32  (1500 mAh 1, 20 SOC, Temperature [C])        float64
#  33  (1500 mAh 1, 40 SOC, 2000 Pounds [Pounds])   float64
#  34  (1500 mAh 1, 40 SOC, Voltage [V])            float64
#  35  (1500 mAh 1, 40 SOC, Temperature [C])        float64
#  36  (1500 mAh 1, 60 SOC, 2000 Pounds [Pounds])   float64
#  37  (1500 mAh 1, 60 SOC, Voltage [V])            float64
#  38  (1500 mAh 1, 60 SOC, Temperature [C])        float64
#  39  (1500 mAh 1, 80 SOC, 2000 Pounds [Pounds])   float64
#  40  (1500 mAh 1, 80 SOC, Voltage [V])            float64
#  41  (1500 mAh 1, 80 SOC, Temperature [C])        float64
#  42  (1500 mAh 1, 100 SOC, 2000 Pounds [Pounds])  float64
#  43  (1500 mAh 1, 100 SOC, Voltage [V])           float64
#  44  (1500 mAh 1, 100 SOC, Temperature [C])       float64
#  45  (1500 mAh 2, 20 SOC, 2000 Pounds [Pounds])   float64
#  46  (1500 mAh 2, 20 SOC, Voltage [V])            float64
#  47  (1500 mAh 2, 20 SOC, Temperature [C])        float64
#  48  (1500 mAh 2, 40 SOC, 2000 Pounds [Pounds])   float64
#  49  (1500 mAh 2, 40 SOC, Voltage [V])            float64
#  50  (1500 mAh 2, 40 SOC, Temperature [C])        float64
#  51  (1500 mAh 2, 60 SOC, 2000 Pounds [Pounds])   float64
#  52  (1500 mAh 2, 60 SOC, Voltage [V])            float64
#  53  (1500 mAh 2, 60 SOC, Temperature [C])        float64
#  54  (1500 mAh 2, 80 SOC, 2000 Pounds [Pounds])   float64
#  55  (1500 mAh 2, 80 SOC, Voltage [V])            float64
#  56  (1500 mAh 2, 80 SOC, Temperature [C])        float64
#  57  (1500 mAh 2, 100 SOC, 2000 Pounds [Pounds])  float64
#  58  (1500 mAh 2, 100 SOC, Voltage [V])           float64
#  59  (1500 mAh 2, 100 SOC, Temperature [C])       float64
#  60  (1500 mAh 3, 20 SOC, 2000 Pounds [Pounds])   float64
#  61  (1500 mAh 3, 20 SOC, Voltage [V])            float64
#  62  (1500 mAh 3, 20 SOC, Temperature [C])        float64
#  63  (1500 mAh 3, 40 SOC, 2000 Pounds [Pounds])   float64
#  64  (1500 mAh 3, 40 SOC, Voltage [V])            float64
#  65  (1500 mAh 3, 40 SOC, Temperature [C])        float64
#  66  (1500 mAh 3, 60 SOC, 2000 Pounds [Pounds])   float64
#  67  (1500 mAh 3, 60 SOC, Voltage [V])            float64
#  68  (1500 mAh 3, 60 SOC, Temperature [C])        float64
#  69  (1500 mAh 3, 80 SOC, 2000 Pounds [Pounds])   float64
#  70  (1500 mAh 3, 80 SOC, Voltage [V])            float64
#  71  (1500 mAh 3, 80 SOC, Temperature [C])        float64
#  72  (1500 mAh 3, 100 SOC, 2000 Pounds [Pounds])  float64
#  73  (1500 mAh 3, 100 SOC, Voltage [V])           float64
#  74  (1500 mAh 3, 100 SOC, Temperature [C])       float64
#  75  (2000 mAh 1, 20 SOC, 2000 Pounds [Pounds])   float64
#  76  (2000 mAh 1, 20 SOC, Voltage [V])            float64
#  77  (2000 mAh 1, 20 SOC, Temperature [C])        float64
#  78  (2000 mAh 1, 40 SOC, 2000 Pounds [Pounds])   float64
#  79  (2000 mAh 1, 40 SOC, Voltage [V])            float64
#  80  (2000 mAh 1, 40 SOC, Temperature [C])        float64
#  81  (2000 mAh 1, 60 SOC, 2000 Pounds [Pounds])   float64
#  82  (2000 mAh 1, 60 SOC, Voltage [V])            float64
#  83  (2000 mAh 1, 60 SOC, Temperature [C])        float64
#  84  (2000 mAh 1, 80 SOC, 2000 Pounds [Pounds])   float64
#  85  (2000 mAh 1, 80 SOC, Voltage [V])            float64
#  86  (2000 mAh 1, 80 SOC, Temperature [C])        float64
#  87  (2000 mAh 1, 100 SOC, 2000 Pounds [Pounds])  float64
#  88  (2000 mAh 1, 100 SOC, Voltage [V])           float64
#  89  (2000 mAh 1, 100 SOC, Temperature [C])       float64
#  90  (2000 mAh 2, 20 SOC, 2000 Pounds [Pounds])   float64
#  91  (2000 mAh 2, 20 SOC, Voltage [V])            float64
#  92  (2000 mAh 2, 20 SOC, Temperature [C])        float64
#  93  (2000 mAh 2, 40 SOC, 2000 Pounds [Pounds])   float64
#  94  (2000 mAh 2, 40 SOC, Voltage [V])            float64
#  95  (2000 mAh 2, 40 SOC, Temperature [C])        float64
#  96  (2000 mAh 2, 60 SOC, 2000 Pounds [Pounds])   float64
#  97  (2000 mAh 2, 60 SOC, Voltage [V])            float64
#  98  (2000 mAh 2, 60 SOC, Temperature [C])        float64
#  99  (2000 mAh 2, 80 SOC, 2000 Pounds [Pounds])   float64
#  100 (2000 mAh 2, 80 SOC, Voltage [V])            float64
#  101 (2000 mAh 2, 80 SOC, Temperature [C])        float64
#  102 (2000 mAh 2, 100 SOC, 2000 Pounds [Pounds])  float64
#  103 (2000 mAh 2, 100 SOC, Voltage [V])           float64
#  104 (2000 mAh 2, 100 SOC, Temperature [C])       float64
# dtypes: float64(105)
# memory usage: 24.3 MB
#                       500 mAh 1                              \
#                          20 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.682
# 0.1                    0.715723    3.745728             NaN
# 0.2                         NaN         NaN          23.680
# 0.3                    0.408984    3.745117             NaN
# 0.4                    0.357861    3.745728          23.683
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          40 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.832
# 0.1                         NaN         NaN             NaN
# 0.2                         NaN         NaN          23.841
# 0.3                    0.920215    3.781433             NaN
# 0.4                    0.817969    3.781738          23.829
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          60 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.319
# 0.1                    1.175830    3.872986             NaN
# 0.2                         NaN         NaN          24.311
# 0.3                    0.408984    3.873291             NaN
# 0.4                    0.869092    3.873596          24.314
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          80 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.816
# 0.1                    0.664600    3.998108             NaN
# 0.2                         NaN         NaN          23.825
# 0.3                    0.408984    3.997803             NaN
# 0.4                    0.306738    3.997498          23.825
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                         100 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.596
# 0.1                    1.175830     4.13208             NaN
# 0.2                         NaN         NaN          24.590
# 0.3                    1.431445     4.13208             NaN
# 0.4                    1.329199     4.13147          24.575
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                       500 mAh 2                              \
#                          20 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.728
# 0.1                    1.073584    3.750610             NaN
# 0.2                    1.022461    3.750916          23.724
# 0.3                    1.278076    3.750610             NaN
# 0.4                         NaN         NaN          23.729
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          40 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.055
# 0.1                    1.533691    3.781128             NaN
# 0.2                         NaN         NaN          24.069
# 0.3                    1.635938    3.781128             NaN
# 0.4                    1.584814    3.781128          24.057
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          60 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.969
# 0.1                   -2.198291    3.866882             NaN
# 0.2                   -2.044922    3.867493          23.989
# 0.3                         NaN         NaN             NaN
# 0.4                         NaN         NaN          23.984
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          80 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.595
# 0.1                         NaN         NaN             NaN
# 0.2                         NaN         NaN          23.592
# 0.3                    0.664600    3.991394             NaN
# 0.4                    0.255615    3.992310          23.591
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                         100 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.716
# 0.1                    1.124707    4.143677             NaN
# 0.2                    1.533691    4.143982          23.714
# 0.3                    1.635938    4.144287             NaN
# 0.4                         NaN         NaN          23.729
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                      1500 mAh 1                              \
#                          20 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.177
# 0.1                         NaN         NaN             NaN
# 0.2                         NaN         NaN          24.165
# 0.3                    1.708984    3.747559             NaN
# 0.4                    2.502441    3.747253          24.175
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          40 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.756
# 0.1                         NaN         NaN             NaN
# 0.2                         NaN         NaN          23.753
# 0.3                    0.976562    3.785706             NaN
# 0.4                         NaN         NaN          23.758
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          60 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.488
# 0.1                    2.319336    3.858948             NaN
# 0.2                         NaN         NaN          23.494
# 0.3                    2.563477    3.858948             NaN
# 0.4                    2.258301    3.858643          23.491
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          80 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.189
# 0.1                    3.173828    3.988953             NaN
# 0.2                         NaN         NaN          24.199
# 0.3                    2.929688    3.988953             NaN
# 0.4                         NaN         NaN          24.192
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                         100 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.780
# 0.1                     2.01416    4.142151             NaN
# 0.2                         NaN         NaN          23.788
# 0.3                     2.13623    4.142456             NaN
# 0.4                         NaN         NaN          23.791
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                      1500 mAh 2                              \
#                          20 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.347
# 0.1                   -0.732422    3.751831             NaN
# 0.2                         NaN         NaN          24.363
# 0.3                   -0.793457    3.751831             NaN
# 0.4                   -1.403809    3.752136          24.344
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          40 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.322
# 0.1                    1.159668    3.785095             NaN
# 0.2                         NaN         NaN          24.321
# 0.3                    1.281738    3.784485             NaN
# 0.4                    1.159668    3.785095          24.318
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          60 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.074
# 0.1                    2.868652    3.872986             NaN
# 0.2                         NaN         NaN          24.076
# 0.3                    2.319336    3.872986             NaN
# 0.4                         NaN         NaN          24.072
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          80 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.955
# 0.1                    1.037598    3.988647             NaN
# 0.2                         NaN         NaN          23.942
# 0.3                    2.014160    3.989563             NaN
# 0.4                    2.136230    3.988953          23.938
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                         100 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.040
# 0.1                   -1.403809    4.137878             NaN
# 0.2                         NaN         NaN          24.036
# 0.3                   -1.342773    4.137878             NaN
# 0.4                   -1.953125    4.137268          24.034
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                      1500 mAh 3                              \
#                          20 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.027
# 0.1                    4.272461    3.754272             NaN
# 0.2                         NaN         NaN          24.039
# 0.3                    3.967285    3.754272             NaN
# 0.4                    3.417969    3.753967          24.027
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          40 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.690
# 0.1                    3.601074    3.782959             NaN
# 0.2                         NaN         NaN          24.697
# 0.3                    4.455566    3.784180             NaN
# 0.4                    4.516602    3.782959          24.704
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          60 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.339
# 0.1                    5.554199     3.85376             NaN
# 0.2                         NaN         NaN          24.342
# 0.3                    5.432129     3.85376             NaN
# 0.4                         NaN         NaN          24.336
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          80 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.680
# 0.1                    4.516602    3.988037             NaN
# 0.2                         NaN         NaN          24.674
# 0.3                    4.211426    3.988037             NaN
# 0.4                         NaN         NaN          24.678
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                         100 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.391
# 0.1                    5.737305    4.145508             NaN
# 0.2                         NaN         NaN          24.389
# 0.3                    5.676270    4.145813             NaN
# 0.4                    5.737305    4.145508          24.394
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                      2000 mAh 1                              \
#                          20 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.626
# 0.1                   -0.061035    3.745728             NaN
# 0.2                    0.549316    3.745728          23.628
# 0.3                   -0.854492    3.745117             NaN
# 0.4                         NaN         NaN          23.626
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          40 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.581
# 0.1                   -2.075195    3.790894             NaN
# 0.2                         NaN         NaN          24.586
# 0.3                   -2.136230    3.791809             NaN
# 0.4                         NaN         NaN          24.578
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          60 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.229
# 0.1                    4.760742    3.853149             NaN
# 0.2                         NaN         NaN          24.232
# 0.3                    4.028320    3.853149             NaN
# 0.4                    4.394531    3.852539          24.224
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          80 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.772
# 0.1                    0.915527    3.989563             NaN
# 0.2                         NaN         NaN          23.769
# 0.3                    1.770020    3.989868             NaN
# 0.4                    1.464844    3.989868          23.760
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                         100 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.206
# 0.1                         NaN         NaN             NaN
# 0.2                         NaN         NaN          24.191
# 0.3                    1.098633    4.146118             NaN
# 0.4                    1.342773    4.146118          24.199
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                      2000 mAh 2                              \
#                          20 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          23.924
# 0.1                    0.183105    3.754272             NaN
# 0.2                         NaN         NaN          23.920
# 0.3                    0.244141    3.754272             NaN
# 0.4                    0.305176    3.753967          23.917
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          40 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.256
# 0.1                     5.79834    3.795471             NaN
# 0.2                         NaN         NaN          24.258
# 0.3                     5.92041    3.794556             NaN
# 0.4                     5.67627    3.794861          24.254
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          60 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.281
# 0.1                    7.202148    3.868103             NaN
# 0.2                         NaN         NaN          24.273
# 0.3                    8.544922    3.870544             NaN
# 0.4                    7.751465    3.868408          24.277
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#                                                              \
#                          80 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.398
# 0.1                    8.117676    3.988342             NaN
# 0.2                    9.277344    3.988342          24.391
# 0.3                    8.300781    3.988342             NaN
# 0.4                         NaN         NaN          24.405
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN             NaN
# 3010.8                      NaN         NaN             NaN
# 3011.0                      NaN         NaN             NaN
# 3011.2                      NaN         NaN             NaN
# 3011.4                      NaN         NaN             NaN
#
#
#                         100 SOC
#            2000 Pounds [Pounds] Voltage [V] Temperature [C]
# Time [Sec]
# 0.0                         NaN         NaN          24.626
# 0.1                    5.554199    4.150696             NaN
# 0.2                    5.371094    4.150391          24.615
# 0.3                    5.920410    4.150391             NaN
# 0.4                         NaN         NaN          24.612
# ...                         ...         ...             ...
# 3010.6                      NaN         NaN          24.503
# 3010.8                      NaN         NaN          24.497
# 3011.0                      NaN         NaN          24.506
# 3011.2                      NaN         NaN          24.499
# 3011.4                      NaN         NaN          24.506
#
# [30009 rows x 105 columns]
#                  500 mAh 1                                                     \
#                     20 SOC                                             40 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         11917.000000  11917.000000     7167.000000         12720.000000
# mean           -125.267985      0.394059       27.662398          -117.296458
# std              37.909750      1.108918        6.976766            39.503107
# min            -335.571680     -0.064392       23.606000          -345.080566
# 25%            -129.954785      0.000610       24.059000          -121.417236
# 50%            -124.229004      0.001831       24.283000          -114.106641
# 75%            -122.030713      0.021667       26.271500          -111.959473
# max               1.635938      3.747864       48.749000             2.198291
#
#                                                                         \
#                                                   60 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  12720.000000     7629.000000         13660.000000  13660.000000
# mean       0.433031       28.652098          -118.967192      0.405137
# std        1.123398        8.973290            39.391807      1.066780
# min       -0.059509       23.577000          -358.065820     -0.057678
# 25%        0.006409       23.990000          -123.308789      0.007019
# 50%        0.010376       24.518000          -113.339795      0.012207
# 75%        0.089416       28.254000          -110.630273      0.162048
# max        3.783569       63.111000             1.635938      3.876953
#
#                                                                           \
#                                     80 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count     8189.000000         13558.000000  13558.000000     8134.000000
# mean        35.512722          -105.082386      0.362067       39.524134
# std         18.611983            32.176086      1.063149       19.054216
# min         24.012000          -306.482666     -0.057068       23.303000
# 25%         24.708000          -113.851025      0.005188       26.147250
# 50%         26.137000          -101.019141      0.011597       28.877000
# 75%         35.486000           -96.520313      0.115356       51.577750
# max         92.944000             0.971338      3.999634       95.381000
#
#                                                                     500 mAh 2  \
#                    100 SOC                                             20 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         20621.000000  20621.000000    12341.000000          7974.000000
# mean           -104.556580      0.230287       31.738533           -97.893185
# std              39.005488      0.921235       10.676061            67.349226
# min            -354.538330     -0.058594       23.789000          -361.388818
# 25%            -114.362256      0.002136       25.347000          -125.443176
# 50%            -105.313477      0.003967       27.099000          -117.787500
# 75%            -101.888232      0.016785       33.820000           -22.979810
# max               2.965137      4.133606       77.753000             4.601074
#
#                                                                       \
#                                                  40 SOC
#        Voltage [V] Temperature [C] 2000 Pounds [Pounds]  Voltage [V]
# count  7974.000000     4772.000000          9061.000000  9061.000000
# mean      0.559564       31.155558           -75.694653     0.538796
# std       1.289850       12.188198            54.213870     1.190594
# min      -0.072021       23.631000          -342.013184    -0.039978
# 25%       0.001831       24.337000           -95.395605     0.007019
# 50%       0.004883       24.700500           -83.074951     0.010986
# 75%       0.069580       30.685500           -68.351514     0.430298
# max       3.752441       62.223000             3.322998     3.782959
#
#                                                                           \
#                                     60 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count     5472.000000         12184.000000  12184.000000     7351.000000
# mean        37.994587           -93.822091      0.326515       32.066237
# std         21.230402            51.719763      1.045647       13.655339
# min         23.931000          -324.120117     -0.054016       23.854000
# 25%         24.735000          -113.454822      0.000916       24.777000
# 50%         26.408000          -104.751123      0.002441       25.642000
# 75%         41.449250          -102.552832      0.021667       31.333000
# max         90.343000             2.044922      3.868103       83.152000
#
#                                                                                \
#                     80 SOC                                            100 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         15396.000000  15396.000000     9284.000000         17068.000000
# mean            -91.980353      0.277443       31.692017           -87.603298
# std              43.283929      0.962598       11.820480            41.338467
# min            -326.318408     -0.059509       23.578000          -327.443115
# 25%            -107.217810      0.003052       24.981750          -103.370801
# 50%             -98.207373      0.005188       26.201500           -93.708545
# 75%             -95.037744      0.034790       32.522000           -87.164795
# max               2.914014      3.992920       75.258000             2.402783
#
#                                               1500 mAh 1                \
#                                                   20 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  17068.000000    10186.000000         15035.000000  15035.000000
# mean       0.364775       34.814258           -40.327416      0.401049
# std        0.932671       13.223819            51.204988      1.045442
# min       -0.020447       23.708000          -429.748535     -0.037231
# 25%        0.021362       25.535000           -35.400391      0.010681
# 50%        0.055847       28.758500           -31.494141      0.012512
# 75%        0.277710       38.482250           -30.822754      0.028076
# max        4.145813       84.331000             2.502441      3.749390
#
#                                                                           \
#                                     40 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count     9082.000000         14520.000000  14520.000000     8635.000000
# mean        30.794615           -33.423730      0.602019       35.315250
# std         13.876336            65.760119      1.118080       18.747742
# min         23.964000          -452.026367     -0.006104       23.670000
# 25%         24.403000           -21.850586      0.038452       24.915500
# 50%         25.004500           -17.211914      0.058289       26.150000
# 75%         27.604750           -15.014648      0.429077       34.144000
# max         83.961000             2.319336      3.786926       92.176000
#
#                                                                                \
#                     60 SOC                                             80 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         18478.000000  18478.000000    11059.000000         14423.000000
# mean            -22.490342      0.641185       35.863874           -19.885155
# std              53.883064      1.081051       19.696804            44.871941
# min            -471.801758      0.001831       23.411000          -388.671875
# 25%             -13.488770      0.051880       24.921000           -12.329102
# 50%             -10.986328      0.086365       26.221000           -10.437012
# 75%              -9.277344      0.602264       34.349500            -8.789062
# max               3.723145      3.860474       93.196000             5.004883
#
#                                                                         \
#                                                  100 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  14423.000000     8686.000000         15168.000000  15168.000000
# mean       0.893009       40.372924           -19.578809      1.042588
# std        1.240173       21.482616            44.738036      1.340285
# min        0.024109       23.962000          -385.314941     -0.013733
# 25%        0.070190       26.200250           -12.756348      0.073853
# 50%        0.154114       28.494500           -10.803223      0.230408
# 75%        1.679840       47.933000            -9.094238      1.784058
# max        3.990173       93.127000             2.502441      4.143982
#
#                                 1500 mAh 2                                \
#                                     20 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count     9157.000000         11116.000000  11116.000000     6686.000000
# mean        42.051277           -34.144338      0.582801       31.816520
# std         21.901105            59.949901      1.161374       12.739686
# min         23.660000          -428.283691     -0.016785       24.263000
# 25%         26.251000           -22.583008      0.028687       25.049000
# 50%         29.683000           -18.676758      0.039673       25.781500
# 75%         54.949000           -18.188477      0.210724       30.222750
# max         92.857000             0.244141      3.753967       72.249000
#
#                                                                                \
#                     40 SOC                                             60 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         13489.000000  13489.000000     8076.000000         14746.000000
# mean            -28.689985      0.606359       34.485609           -25.773893
# std              49.471961      1.067323       15.914327            58.831502
# min            -395.080566     -0.019531       24.129000          -460.021973
# 25%             -21.606445      0.059814       25.204000           -14.221191
# 50%             -17.456055      0.096436       26.578000           -12.817383
# 75%             -16.296387      0.483093       34.735750           -11.230469
# max               1.831055      3.786621       81.056000             4.638672
#
#                                                                         \
#                                                   80 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  14746.000000     8871.000000         16674.000000  16674.000000
# mean       0.774540       38.205316           -19.317539      0.847436
# std        1.138953       21.059821            50.699792      1.194520
# min        0.014954       23.810000          -437.988281      0.012817
# 25%        0.069275       25.194000           -10.253906      0.086975
# 50%        0.146790       27.168000            -8.728027      0.168457
# 75%        1.156540       40.855000            -7.812500      1.222382
# max        3.875427       99.382000             8.056641      3.990479
#
#                                                                           \
#                                    100 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count    10079.000000         18916.000000  18916.000000     11395.00000
# mean        38.930431           -19.335793      1.133061        38.73875
# std         22.012227            58.817997      1.324050        20.33706
# min         23.747000          -490.600586      0.087891        23.98300
# 25%         25.475000            -8.789062      0.179138        25.75750
# 50%         27.303000            -7.629395      0.352783        27.83100
# 75%         41.170000            -6.958008      2.116470        43.75150
# max         97.468000            16.967773      4.140930        93.00800
#
#                 1500 mAh 3                                                     \
#                     20 SOC                                             40 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         13064.000000  13064.000000     7406.000000         15814.000000
# mean            -36.921672      0.506527       32.429212           -29.777124
# std              65.956987      1.127650       14.509294            57.369452
# min            -479.431152     -0.035706       23.948000          -466.247559
# 25%             -27.847290      0.022583       25.058250           -22.888184
# 50%             -23.254395      0.026855       25.865500           -17.456055
# 75%             -22.460938      0.111084       30.598250           -16.418457
# max               4.516602      3.759155       81.358000             5.249023
#
#                                                                         \
#                                                   60 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  15814.000000     9045.000000         16681.000000  16681.000000
# mean       0.526777       34.501262           -26.394150      0.689098
# std        1.051694       17.231672            61.001983      1.126922
# min        0.005798       24.381000          -487.609863     -0.000610
# 25%        0.040588       25.334000           -16.113281      0.053711
# 50%        0.055237       26.617000           -14.099121      0.088196
# 75%        0.251389       32.284000           -11.474609      0.694275
# max        3.787231       95.373000             7.080078      3.857117
#
#                                                                           \
#                                     80 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count     9946.000000         21359.000000  21359.000000    12078.000000
# mean        37.565348           -15.855390      0.759109       37.885623
# std         20.636643            47.066092      1.138924       20.347875
# min         24.192000          -450.439453     -0.000305       24.393000
# 25%         25.767250            -8.239746      0.083923       25.813000
# 50%         27.383000            -7.019043      0.147400       27.795000
# 75%         36.950250            -6.347656      0.767822       37.876250
# max         99.129000             6.591797      3.991394       95.795000
#
#                                                                    2000 mAh 1  \
#                    100 SOC                                             20 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         20753.000000  20753.000000    11809.000000         15483.000000
# mean            -17.178742      0.763819       39.009829           -39.607819
# std              47.739919      1.183406       21.440960            68.711745
# min            -451.293945     -0.006104       24.194000          -517.395020
# 25%             -11.230469      0.060120       25.685000           -29.846191
# 50%              -8.666992      0.111084       27.997000           -25.573730
# 75%              -7.263184      0.979614       42.648000           -24.841309
# max               7.080078      4.149780      102.127000             4.943848
#
#                                                                         \
#                                                   40 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  15483.000000     8867.000000         15338.000000  15338.000000
# mean       0.388240       33.480556           -46.450253      1.201529
# std        1.041648       16.862047            63.172404      1.435383
# min       -0.040588       23.543000          -499.206543      0.015564
# 25%        0.008240       25.171000           -49.911499      0.081482
# 50%        0.012207       26.358000           -30.273438      0.273132
# 75%        0.027771       30.419500           -27.465820      2.994003
# max        3.750610       93.149000             0.122070      3.798828
#
#                                                                           \
#                                     60 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count     8726.000000         23606.000000  23606.000000    13364.000000
# mean        40.804222           -54.522095      1.908921       40.749890
# std         21.368016            48.058940      1.553236       15.990672
# min         24.154000          -488.769531      0.137634       24.071000
# 25%         25.710250           -63.659668      0.311279       25.886750
# 50%         28.606500           -45.166016      1.282043       32.065500
# 75%         51.313000           -38.635254      3.596802       56.828750
# max         86.549000             5.798340      3.857727       67.765000
#
#                                                                                \
#                     80 SOC                                            100 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         24941.000000  24941.000000    14192.000000         21652.000000
# mean            -55.172199      1.973294       43.234999           -46.741017
# std              47.894087      1.565694       17.341964            55.738657
# min            -493.041992      0.130920       23.701000          -502.319336
# 25%             -62.866211      0.331726       26.520000           -63.064575
# 50%             -47.607422      1.612854       35.324500           -29.907227
# 75%             -38.513184      3.593750       60.191500           -23.010254
# max               2.441406      3.992615       74.759000             4.943848
#
#                                               2000 mAh 2                \
#                                                   20 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  21652.000000    12382.000000         12544.000000  12544.000000
# mean       1.462936       45.810271           -44.435088      1.008805
# std        1.524430       22.224028            65.150103      1.386401
# min        0.007324       23.920000          -476.562500      0.015259
# 25%        0.142517       26.860000           -40.969849      0.057373
# 50%        0.551605       33.576500           -29.113770      0.130920
# 75%        3.096619       73.020250           -26.611328      2.211685
# max        4.150696       83.699000             0.610352      3.757935
#
#                                                                           \
#                                     40 SOC
#       Temperature [C] 2000 Pounds [Pounds]   Voltage [V] Temperature [C]
# count     7169.000000         19123.000000  19123.000000    10909.000000
# mean        35.622703           -42.098810      0.888314       38.241926
# std         17.006310            56.693711      1.352396       20.788121
# min         23.634000          -484.863281      0.006409       24.094000
# 25%         25.204000           -39.428711      0.042419       25.240000
# 50%         26.688000           -27.221680      0.073242       27.151000
# 75%         38.868000           -25.695801      1.288452       40.888000
# max         81.492000             6.347656      3.797913       87.564000
#
#                                                                                \
#                     60 SOC                                             80 SOC
#       2000 Pounds [Pounds]   Voltage [V] Temperature [C] 2000 Pounds [Pounds]
# count         23131.000000  23131.000000    13183.000000         25610.000000
# mean            -44.167127      1.701504       37.658106           -55.880483
# std              52.571081      1.553781       14.061686            49.461024
# min            -484.375000      0.085754       24.082000          -500.183105
# 25%             -52.185059      0.216217       25.624000           -68.725586
# 50%             -31.616211      0.806885       29.642000           -45.471191
# 75%             -26.672363      3.533630       51.757500           -36.010742
# max              14.099121      3.872375       66.669000            11.230469
#
#                                                                         \
#                                                  100 SOC
#         Voltage [V] Temperature [C] 2000 Pounds [Pounds]   Voltage [V]
# count  25610.000000    14579.000000         26419.000000  26419.000000
# mean       1.841387       38.506120           -27.446479      0.897860
# std        1.642416       13.309942            49.920469      1.312336
# min        0.059204       24.214000          -478.576660      0.007019
# 25%        0.171204       25.915500           -28.564453      0.052490
# 50%        1.068420       31.907000           -13.977051      0.150146
# 75%        3.597412       52.442000           -10.681152      1.275482
# max        3.992615       59.503000            18.005371      4.154968
#
#
#
#       Temperature [C]
# count    15058.000000
# mean        36.462223
# std         16.302375
# min         24.314000
# 25%         25.242250
# 50%         27.804000
# 75%         41.698750
# max         72.513000

# %% [markdown]
# # Save Data

# %%
filename = os.path.join(results_dirname, results_basename)
print(filename)
data_df.to_csv(filename, compression="gzip")
# Out:
# ../data/raw_mechanical_loading_data.csv.gz
